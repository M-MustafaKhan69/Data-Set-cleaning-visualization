# %%
import numpy as np
import pandas as pd

# %%
inf=pd.read_csv("C:\\Users\\129mu\\Desktop\\data_cleaning_yt\\dataset.csv",encoding="latin1")
inf
# Out:
#     Rank   Peak All Time Peak    ActualÂ gross  \
# 0      1      1             2     $780,000,000
# 1      2      1          7[2]     $579,800,000
# 2      3   1[4]          2[5]     $411,000,000
# 3      4   2[7]         10[7]     $397,300,000
# 4      5   2[4]           NaN     $345,675,146
# 5      6   2[4]         10[9]     $305,158,363
# 6      7  2[10]           NaN     $280,000,000
# 7      7    NaN           NaN     $257,600,000
# 8      9    NaN           NaN     $256,084,556
# 9     10    NaN           NaN     $250,400,000
# 10    11    NaN           NaN  $229,100,000[b]
# 11    12    NaN        14[17]     $227,400,000
# 12    13    NaN           NaN     $204,000,000
# 13    14  1[20]           NaN     $200,000,000
# 14    15   2[c]           NaN     $194,000,000
# 15    16    NaN           NaN     $184,000,000
# 16    17    NaN           NaN     $170,000,000
# 17    18    NaN           NaN     $169,800,000
# 18    19    NaN           NaN  $167,700,000[e]
# ...

# %%
inf["Peak"]=inf["Peak"].astype("str").str.extract(r"(\d+)")[0]
inf["All Time Peak"]=inf["All Time Peak"].astype("str").str.extract(r"(\d+)")[0]
inf
# Out:
#     Rank Peak All Time Peak    ActualÂ gross  \
# 0      1    1             2     $780,000,000
# 1      2    1             7     $579,800,000
# 2      3    1             2     $411,000,000
# 3      4    2            10     $397,300,000
# 4      5    2           NaN     $345,675,146
# 5      6    2            10     $305,158,363
# 6      7    2           NaN     $280,000,000
# 7      7  NaN           NaN     $257,600,000
# 8      9  NaN           NaN     $256,084,556
# 9     10  NaN           NaN     $250,400,000
# 10    11  NaN           NaN  $229,100,000[b]
# 11    12  NaN            14     $227,400,000
# 12    13  NaN           NaN     $204,000,000
# 13    14    1           NaN     $200,000,000
# 14    15    2           NaN     $194,000,000
# 15    16  NaN           NaN     $184,000,000
# 16    17  NaN           NaN     $170,000,000
# 17    18  NaN           NaN     $169,800,000
# 18    19  NaN           NaN  $167,700,000[e]
# 19    20  NaN           NaN     $150,000,000
#
# ...

# %%
inf["Peak"]=inf["Peak"].fillna(-1)
inf["All Time Peak"]=inf["All Time Peak"].fillna(-1)
inf
# Out:
#     Rank Peak All Time Peak    ActualÂ gross  \
# 0      1    1             2     $780,000,000
# 1      2    1             7     $579,800,000
# 2      3    1             2     $411,000,000
# 3      4    2            10     $397,300,000
# 4      5    2            -1     $345,675,146
# 5      6    2            10     $305,158,363
# 6      7    2            -1     $280,000,000
# 7      7   -1            -1     $257,600,000
# 8      9   -1            -1     $256,084,556
# 9     10   -1            -1     $250,400,000
# 10    11   -1            -1  $229,100,000[b]
# 11    12   -1            14     $227,400,000
# 12    13   -1            -1     $204,000,000
# 13    14    1            -1     $200,000,000
# 14    15    2            -1     $194,000,000
# 15    16   -1            -1     $184,000,000
# 16    17   -1            -1     $170,000,000
# 17    18   -1            -1     $169,800,000
# 18    19   -1            -1  $167,700,000[e]
# 19    20   -1            -1     $150,000,000
#
# ...

# %%
inf["Peak"]=inf["Peak"].astype("int")
inf["All Time Peak"]=inf["All Time Peak"].astype("int")

# %%
inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Rank                               20 non-null     int64
#  1   Peak                               20 non-null     int64
#  2   All Time Peak                      20 non-null     int64
#  3   ActualÂ gross                      20 non-null     object
#  4   AdjustedÂ gross (in 2022 dollars)  20 non-null     object
#  5   Artist                             20 non-null     object
#  6   Tour title                         20 non-null     object
#  7   Year(s)                            20 non-null     object
#  8   Shows                              20 non-null     int64
#  9   Average gross                      20 non-null     object
#  10  Ref.                               20 non-null     object
# dtypes: int64(4), object(7)
# ...

# %%
inf=inf.rename(columns={"ActualÂ gross":"Actual Gross","AdjustedÂ gross (in 2022 dollars)":"Adjusted Gross"})
inf.columns
# Out:
# Index(['Rank', 'Peak', 'All Time Peak', 'ActualÂ gross',
#        'AdjustedÂ gross (in 2022 dollars)', 'Artist', 'Tour title', 'Year(s)',
#        'Shows', 'Average gross', 'Ref.'],
#       dtype='object')

# %%
cols=list(inf.columns)
cols[3]="Actual Gross"
cols[4]="Adjusted gross"
inf.columns = cols

# %%
inf["Shows"]<0
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Shows, dtype: bool

# %%
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000      BeyoncÃ©
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      7    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401      BeyoncÃ©
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896      BeyoncÃ©
# ...

# %%
import unicodedata

inf["Artist"]=inf["Artist"].apply(lambda x: unicodedata.normalize("NFKD",str(x)))
inf["Artist"]=(inf["Artist"].str.encode("ascii","ignore").str.decode("utf-8"))
inf["Artist"]=inf["Artist"].str.replace(r"[^\w\s]+","",regex=True)
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      7    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
years = inf["Year(s)"].astype("str").str.split(r"\D+", expand=True, regex=True)

inf["Start_year"] = years[0].astype("Int64")
inf["End_year"]   = years[1].astype("Int64")
inf["End_year"] = inf["End_year"].fillna(inf["Start_year"])
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      7    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      7    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf=inf.drop(columns=["Year(s)","Ref."])

# %%
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      7    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf.loc[7, "Rank"] = 8
inf.loc[8,"Rank"]=9
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      8    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            20 non-null     int64
#  1   Peak            20 non-null     int64
#  2   All Time Peak   20 non-null     int64
#  3   Actual Gross    20 non-null     object
#  4   Adjusted gross  20 non-null     object
#  5   Artist          20 non-null     object
#  6   Tour title      20 non-null     object
#  7   Shows           20 non-null     int64
#  8   Average gross   20 non-null     object
#  9   Start_year      20 non-null     Int64
#  10  End_year        20 non-null     Int64
# dtypes: Int64(2), int64(4), object(5)
# memory usage: 1.9+ KB

# %%
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      8    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      8    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf["Tour title"] = (
    inf["Tour title"]
    .astype("str")
    .str.replace(r"\[[^\]]*\]", "", regex=True)
    .str.replace(r"\W+", " ", regex=True)
    .str.strip()
)
inf
# Out:
#     Rank  Peak  All Time Peak     Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     $780,000,000   $780,000,000  Taylor Swift
# 1      2     1              7     $579,800,000   $579,800,000       BeyoncA
# 2      3     1              2     $411,000,000   $560,622,615       Madonna
# 3      4     2             10     $397,300,000   $454,751,555          Pink
# 4      5     2             -1     $345,675,146   $402,844,849  Taylor Swift
# 5      6     2             10     $305,158,363   $388,978,496       Madonna
# 6      7     2             -1     $280,000,000   $381,932,682   Celine Dion
# 7      8    -1             -1     $257,600,000   $257,600,000          Pink
# 8      9    -1             -1     $256,084,556   $312,258,401       BeyoncA
# 9     10    -1             -1     $250,400,000   $309,141,878  Taylor Swift
# 10    11    -1             -1  $229,100,000[b]   $283,202,896       BeyoncA
# ...

# %%
inf["Actual Gross"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        $780,000,000
# 1        $579,800,000
# 2        $411,000,000
# 3        $397,300,000
# 4        $345,675,146
# 5        $305,158,363
# 6        $280,000,000
# 7        $257,600,000
# 8        $256,084,556
# 9        $250,400,000
# 10    $229,100,000[b]
# 11       $227,400,000
# 12       $204,000,000
# 13       $200,000,000
# 14       $194,000,000
# 15       $184,000,000
# 16       $170,000,000
# 17       $169,800,000
# 18    $167,700,000[e]
# 19       $150,000,000
# Name: Actual Gross, dtype: object>

# %%
inf["Actual Gross"]=inf["Actual Gross"].astype("str").str.replace(r"\[[^\]]*\]", "", regex=True).str.replace(r"[^0-9.]","",regex=True).astype("int")

# %%
inf
# Out:
#     Rank  Peak  All Time Peak  Actual Gross Adjusted gross        Artist  \
# 0      1     1              2     780000000   $780,000,000  Taylor Swift
# 1      2     1              7     579800000   $579,800,000       BeyoncA
# 2      3     1              2     411000000   $560,622,615       Madonna
# 3      4     2             10     397300000   $454,751,555          Pink
# 4      5     2             -1     345675146   $402,844,849  Taylor Swift
# 5      6     2             10     305158363   $388,978,496       Madonna
# 6      7     2             -1     280000000   $381,932,682   Celine Dion
# 7      8    -1             -1     257600000   $257,600,000          Pink
# 8      9    -1             -1     256084556   $312,258,401       BeyoncA
# 9     10    -1             -1     250400000   $309,141,878  Taylor Swift
# 10    11    -1             -1     229100000   $283,202,896       BeyoncA
# 11    12    -1             14     227400000   $295,301,479     Lady Gaga
# ...

# %%
inf["Adjusted gross"]=inf["Adjusted gross"].astype("str").str.replace(r"\[[^\]]*\]","",regex=True).str.replace(r"[^0-9.]","",regex=True).astype("int")

# %%
inf
# Out:
#     Rank  Peak  All Time Peak  Actual Gross  Adjusted gross        Artist  \
# 0      1     1              2     780000000       780000000  Taylor Swift
# 1      2     1              7     579800000       579800000       BeyoncA
# 2      3     1              2     411000000       560622615       Madonna
# 3      4     2             10     397300000       454751555          Pink
# 4      5     2             -1     345675146       402844849  Taylor Swift
# 5      6     2             10     305158363       388978496       Madonna
# 6      7     2             -1     280000000       381932682   Celine Dion
# 7      8    -1             -1     257600000       257600000          Pink
# 8      9    -1             -1     256084556       312258401       BeyoncA
# 9     10    -1             -1     250400000       309141878  Taylor Swift
# 10    11    -1             -1     229100000       283202896       BeyoncA
# 11    12    -1             14     227400000       295301479     Lady Gaga
# ...

# %%
inf["Average gross"]=inf["Average gross"].astype("str").str.replace(r"\[[^\]]*\]","",regex=True).str.replace(r"[^0-9.]","",regex=True).astype("int")
inf
# Out:
#     Rank  Peak  All Time Peak  Actual Gross  Adjusted gross        Artist  \
# 0      1     1              2     780000000       780000000  Taylor Swift
# 1      2     1              7     579800000       579800000       BeyoncA
# 2      3     1              2     411000000       560622615       Madonna
# 3      4     2             10     397300000       454751555          Pink
# 4      5     2             -1     345675146       402844849  Taylor Swift
# 5      6     2             10     305158363       388978496       Madonna
# 6      7     2             -1     280000000       381932682   Celine Dion
# 7      8    -1             -1     257600000       257600000          Pink
# 8      9    -1             -1     256084556       312258401       BeyoncA
# 9     10    -1             -1     250400000       309141878  Taylor Swift
# 10    11    -1             -1     229100000       283202896       BeyoncA
# 11    12    -1             14     227400000       295301479     Lady Gaga
# ...

# %%
print("cleaned data:")
inf
# Out:
# cleaned data:
#     Rank  Peak  All Time Peak  Actual Gross  Adjusted gross        Artist  \
# 0      1     1              2     780000000       780000000  Taylor Swift
# 1      2     1              7     579800000       579800000       BeyoncA
# 2      3     1              2     411000000       560622615       Madonna
# 3      4     2             10     397300000       454751555          Pink
# 4      5     2             -1     345675146       402844849  Taylor Swift
# 5      6     2             10     305158363       388978496       Madonna
# 6      7     2             -1     280000000       381932682   Celine Dion
# 7      8    -1             -1     257600000       257600000          Pink
# 8      9    -1             -1     256084556       312258401       BeyoncA
# 9     10    -1             -1     250400000       309141878  Taylor Swift
# 10    11    -1             -1     229100000       283202896       BeyoncA
# ...

# %%
print(type(inf))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
type(inf), inf.shape
# Out:
# (pandas.core.frame.DataFrame, (20, 11))

# %%
inf.to_csv(r"C:\Users\129mu\Desktop\DATA_CLEANING_YT\cleaned_tour_data.csv", index=False)
